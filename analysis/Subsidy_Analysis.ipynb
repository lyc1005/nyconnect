# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import os as os

np.random.seed(1728)

# Adjust directory accordingly
os.chdir('C:\\Users\\wesch\\OneDrive\\20 Spring Summer Urban Science Intensive\\nyconnect\\data')
# Out:
# c:\users\wesch\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# load datasets
subscription = pd.read_csv("./ACS_Internet_Subscription/subscription_acs_2018.csv")
income = pd.read_csv("./Demographics/Income/household_income_acs2018.csv")
census_tracts = gpd.read_file("./2010_Census_Tracts/geo_export_0ca1f0a1-f242-497a-9f86-91b88fc18647.shp")
broadband_pricing = pd.read_csv("./Broadband Prices/broadband_price_census2018.csv")
all_vars = pd.read_csv("./Demographics/Aggregated_Demographics.csv")

# %%
# bottom decile
bottom_decile_subscription = all_vars.loc[:, ['HH 0-10k', 'HH 10k-15k', "No_Internet"]]
bottom_decile_subscription = bottom_decile_subscription.assign(
    bottom_decile = lambda x: x["HH 0-10k"] + x["HH 10k-15k"])

# %%
sns.lmplot(x = "bottom_decile", y = "No_Internet", data = bottom_decile_subscription)

# %%
sns.lmplot(x = "HH 15k-25k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 25k-35k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 35k-50k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 50k-75k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 75k-100k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 100k-150k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 150k-200k", y = "No_Internet", data = all_vars)

# %%
sns.lmplot(x = "HH 200k-UP", y = "No_Internet", data = all_vars)
